# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-16e9230a-8fdf-4d88-9254-87e73ca5a546" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16e9230a-8fdf-4d88-9254-87e73ca5a546">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Without_stopwords_final.csv to Without_stopwords_final.csv

# %%
df = pd.read_csv("Without_stopwords_final.csv",encoding="utf16",header = None,index_col = False, names = ["Text", "Value"])

df.head()
# Out:
#                                                 Text  Value
# 0  दिनेश कार्तिक अलावा युवा केदार जाधव बेहतर प्रत...      2
# 1                          परफॉर्मेंस चार्ट शायद कभी      2
# 2                            स दवा दिन तबीयत बहाल गई      1
# 3  चुनाव आयोग नाराज़ बंगाल इतने दिनों हिंसा रही च...      0
# 4  दौर इन्सान बरदाश्त हद हर बार जी उठता कितनी दफ़...      2

# %%
count = df['Value'].value_counts()
print(count)
# Out:
# 2    3850
# 1    3816
# 0    3437
# Name: Value, dtype: int64

# %%
from matplotlib import pyplot as plt
import numpy as np

font = {'family' : 'normal',
        'size'   : 22}

plt.rc('font', **font)
  

key = [ 'Negative', 'Positive' , 'Neutral']
  
# Creating plot
fig = plt.figure(figsize =(15, 10.5))
plt.pie(count, labels = key, autopct='%0.0001f%%')
  
# show plot
plt.show()

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5498e313-11fa-46f2-a631-c93ea932c937" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5498e313-11fa-46f2-a631-c93ea932c937">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final_stopwords.txt to final_stopwords.txt

# %%
df1 = pd.read_csv("final_stopwords.txt",encoding="utf8",header = None,index_col = False, names = ["words"])

print(df1['words'].size)
df1.head()
# Out:
# 248
#    words
# 0    मैं
# 1  मुझको
# 2   मेरा
# 3   अपने
# 4   हमने

# %%
#pd.set_option('display.max_rows', 242)

wordCount = df1['words'].value_counts()
print(wordCount.head(10))
# Out:
# खुद      3
# हैं      2
# किया     2
# अपने     2
# कि       2
# दोनो     1
# लेकिन    1
# ऊपर      1
# होती     1
# अब       1
# Name: words, dtype: int64

# %%
key = labels
freqWords = wordCount.head(10)

print (freqWords)

freqList = wordCount.head(10).tolist()

print (freqList)

# Creating plot
fig = plt.figure(figsize =(15, 10.5))
plt.pie(freqWords)
  
# show plot
plt.show()
# Out:
# खुद      3
# हैं      2
# किया     2
# अपने     2
# कि       2
# दोनो     1
# लेकिन    1
# ऊपर      1
# होती     1
# अब       1
# Name: words, dtype: int64
# [3, 2, 2, 2, 2, 1, 1, 1, 1, 1]

# %%
*
